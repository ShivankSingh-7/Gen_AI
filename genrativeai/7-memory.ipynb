# %% [markdown]
# ### Agent With Memory

# %%
import langchain
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_groq import ChatGroq

llm = ChatGroq(model="llama-3.3-70b-versatile")
llm
# Out:
# ChatGroq(profile={'max_input_tokens': 131072, 'max_output_tokens': 32768, 'image_inputs': False, 'audio_inputs': False, 'video_inputs': False, 'image_outputs': False, 'audio_outputs': False, 'video_outputs': False, 'reasoning_output': False, 'tool_calling': True}, client=<groq.resources.chat.completions.Completions object at 0x00000230855426D0>, async_client=<groq.resources.chat.completions.AsyncCompletions object at 0x00000230856A9AD0>, model_name='llama-3.3-70b-versatile', model_kwargs={}, groq_api_key=SecretStr('**********'))

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

# %%
agent = create_agent(
    model=llm,
    checkpointer=InMemorySaver()
)

# %%
### Run with thread id 
config={"configurable":{"thread_id":"test1"}}

# %%
from langchain_core.messages import HumanMessage, SystemMessage
response = agent.invoke({"messages":[HumanMessage(content="Hi my name is Krish")]}, config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hi my name is Krish', additional_kwargs={}, response_metadata={}, id='f5e17e78-4884-4a39-8770-5e0ad585cd49'),
#   AIMessage(content="Hello Krish, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 40, 'total_tokens': 66, 'completion_time': 0.047348357, 'completion_tokens_details': None, 'prompt_time': 0.007386202, 'prompt_tokens_details': None, 'queue_time': 0.304615088, 'total_time': 0.054734559}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_0761e44d7b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d66c4-84b2-76e2-8cd6-4491c0e59239-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 26, 'total_tokens': 66})]}

# %%
agent.invoke({"messages":[HumanMessage(content="What is my name?")]}, config=config)
# Out:
# {'messages': [HumanMessage(content='Hi my name is Krish', additional_kwargs={}, response_metadata={}, id='f5e17e78-4884-4a39-8770-5e0ad585cd49'),
#   AIMessage(content="Hello Krish, it's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 26, 'prompt_tokens': 40, 'total_tokens': 66, 'completion_time': 0.047348357, 'completion_tokens_details': None, 'prompt_time': 0.007386202, 'prompt_tokens_details': None, 'queue_time': 0.304615088, 'total_time': 0.054734559}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_0761e44d7b', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d66c4-84b2-76e2-8cd6-4491c0e59239-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 26, 'total_tokens': 66}),
#   HumanMessage(content='What is my name?', additional_kwargs={}, response_metadata={}, id='9d929b52-6602-4691-8818-17bbf3d511ff'),
#   AIMessage(content='Your name is Krish.', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 6, 'prompt_tokens': 80, 'total_tokens': 86, 'completion_time': 0.006718065, 'completion_tokens_details': None, 'prompt_time': 0.016428984, 'prompt_tokens_details': None, 'queue_time': 0.162316923, 'total_time': 0.023147049}, 'model_name': 'llama-3.3-70b-versatile', 'system_fingerprint': 'fp_45180df409', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--019d66c5-657d-7932-a6fa-dfda161c281c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 80, 'output_tokens': 6, 'total_tokens': 86})]}
